# %%
IMPORTING LIBRARIES

# %%
import pandas as pd # data handling
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# LOADING THE DATASET

# %%
df = pd.read_csv('/content/hotel_booking.csv')

# %% [markdown]
# EXPLORATORY DATA ANALYSIS and DATA CLEANING

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  customer_type  \
# 0                        0                     0       2  ...      Transient
# ...

# %%
df.tail()
# Out:
#             hotel  is_canceled  lead_time  arrival_date_year  \
# 64537  City Hotel            1         30               2017
# 64538  City Hotel            1         98               2017
# 64539  City Hotel            1        193               2017
# 64540  City Hotel            1        154               2017
# 64541  City Hotel            1         18               2017
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 64537              March                        11                         12
# 64538              March                        11                         12
# 64539              March                        11                         12
# 64540              March                        11                         12
# 64541              March                        11                         12
#
#        stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# ...

# %%
df.shape
# Out:
# (64542, 36)

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date', 'name', 'email',
#        'phone-number', 'credit_card'],
#       dtype='object')

# %%
df.info()
# datatypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64542 entries, 0 to 64541
# Data columns (total 36 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           64542 non-null  object
#  1   is_canceled                     64542 non-null  int64
#  2   lead_time                       64542 non-null  int64
#  3   arrival_date_year               64542 non-null  int64
#  4   arrival_date_month              64542 non-null  object
#  5   arrival_date_week_number        64542 non-null  int64
#  6   arrival_date_day_of_month       64542 non-null  int64
#  7   stays_in_weekend_nights         64542 non-null  int64
#  8   stays_in_week_nights            64542 non-null  int64
#  9   adults                          64542 non-null  int64
#  10  children                        64538 non-null  float64
#  11  babies                          64542 non-null  int64
# ...

# %%
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'])
# converting reservation_status date from object datatype to datetime datatype

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64542 entries, 0 to 64541
# Data columns (total 36 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           64542 non-null  object
#  1   is_canceled                     64542 non-null  int64
#  2   lead_time                       64542 non-null  int64
#  3   arrival_date_year               64542 non-null  int64
#  4   arrival_date_month              64542 non-null  object
#  5   arrival_date_week_number        64542 non-null  int64
#  6   arrival_date_day_of_month       64542 non-null  int64
#  7   stays_in_weekend_nights         64542 non-null  int64
#  8   stays_in_week_nights            64542 non-null  int64
#  9   adults                          64542 non-null  int64
#  10  children                        64538 non-null  float64
#  11  babies                          64542 non-null  int64
# ...

# %%
cat = df.describe(include = 'object')
# describe is primarily for numeric datatypes but, include is a parameter that can help in using it for object datatype.
# object is a string or key-value pair datatype

# %%
for col in cat.columns:
  print(col)
  print(df[col].unique())
  print('-'*100)
# Out:
# hotel
# ['Resort Hotel' 'City Hotel']
# ----------------------------------------------------------------------------------------------------
# arrival_date_month
# ['July' 'August' 'September' 'October' 'November' 'December' 'January'
#  'February' 'March' 'April' 'May' 'June']
# ----------------------------------------------------------------------------------------------------
# meal
# ['BB' 'FB' 'HB' 'SC' 'Undefined']
# ----------------------------------------------------------------------------------------------------
# country
# ['PRT' 'GBR' 'USA' 'ESP' 'IRL' 'FRA' nan 'ROU' 'NOR' 'OMN' 'ARG' 'POL'
#  'DEU' 'BEL' 'CHE' 'CN' 'GRC' 'ITA' 'NLD' 'DNK' 'RUS' 'SWE' 'AUS' 'EST'
#  'CZE' 'BRA' 'FIN' 'MOZ' 'BWA' 'LUX' 'SVN' 'ALB' 'IND' 'CHN' 'MEX' 'MAR'
#  'UKR' 'SMR' 'LVA' 'PRI' 'SRB' 'CHL' 'AUT' 'BLR' 'LTU' 'TUR' 'ZAF' 'AGO'
#  'ISR' 'CYM' 'ZMB' 'CPV' 'ZWE' 'DZA' 'KOR' 'CRI' 'HUN' 'ARE' 'TUN' 'JAM'
#  'HRV' 'HKG' 'IRN' 'GEO' 'AND' 'GIB' 'URY' 'JEY' 'CAF' 'CYP' 'COL' 'GGY'
# ...

# %%
df.isnull().sum()
# missing values
# Out:
# hotel                                 0
# is_canceled                           0
# lead_time                             0
# arrival_date_year                     0
# arrival_date_month                    0
# arrival_date_week_number              0
# arrival_date_day_of_month             0
# stays_in_weekend_nights               0
# stays_in_week_nights                  0
# adults                                0
# children                              4
# babies                                0
# meal                                  0
# country                             482
# market_segment                        0
# distribution_channel                  0
# is_repeated_guest                     0
# previous_cancellations                0
# previous_bookings_not_canceled        0
# reserved_room_type                    0
# assigned_room_type                    0
# booking_changes                       0
# deposit_type                          0
# ...

# %%
df.drop(['company','agent','name','email','phone-number','credit_card'], axis = 1, inplace = True)
# dropping missing/unnecessary values
# axis=1 is for columns and inplace=True makes changes in the dataset
df.dropna(inplace = True)

# %%
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# ...

# %%
df.isnull()
# Out:
#        hotel  is_canceled  lead_time  arrival_date_year  arrival_date_month  \
# 0      False        False      False              False               False
# 1      False        False      False              False               False
# 2      False        False      False              False               False
# 3      False        False      False              False               False
# 4      False        False      False              False               False
# ...      ...          ...        ...                ...                 ...
# 64536  False        False      False              False               False
# 64537  False        False      False              False               False
# 64538  False        False      False              False               False
# 64539  False        False      False              False               False
# 64540  False        False      False              False               False
#
# ...

# %%
df.describe()
# Out:
#         is_canceled     lead_time  arrival_date_year  \
# count  64055.000000  64055.000000       64055.000000
# mean       0.465116    104.449645        2016.016205
# std        0.498786    107.317713           0.685495
# min        0.000000      0.000000        2015.000000
# 25%        0.000000     19.000000        2016.000000
# 50%        0.000000     70.000000        2016.000000
# 75%        1.000000    161.000000        2016.000000
# max        1.000000    737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count              64055.000000               64055.000000
# mean                  27.947904                  15.705082
# std                   14.148041                   8.834475
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   29.000000                  16.000000
# 75%                   40.000000                  23.000000
# ...

# %%
df['adr'].plot(kind = 'box')
# boxplot for outlier
# Out:
# <Axes: >

# %%
df = df[df['adr']<4500]

# %%
df.describe()
# Out:
#         is_canceled     lead_time  arrival_date_year  \
# count  64054.000000  64054.000000       64054.000000
# mean       0.465108    104.450729        2016.016205
# std        0.498785    107.318200           0.685500
# min        0.000000      0.000000        2015.000000
# 25%        0.000000     19.000000        2016.000000
# 50%        0.000000     70.000000        2016.000000
# 75%        1.000000    161.000000        2016.000000
# max        1.000000    737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count              64054.000000               64054.000000
# mean                  27.948138                  15.704936
# std                   14.148028                   8.834468
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   29.000000                  16.000000
# 75%                   40.000000                  23.000000
# ...

# %% [markdown]
# ANALYSIS ON CLEAN DATA

# %%
cancelled_perc = df['is_canceled'].value_counts(normalize = True)
cancelled_perc
# Out:
# 0    0.534892
# 1    0.465108
# Name: is_canceled, dtype: float64

# %%
plt.figure(figsize = (8,8))
plt.title("Reservation status count")
plt.bar(['Not Cancelled','Calcelled'],df['is_canceled'].value_counts())
# Out:
# <BarContainer object of 2 artists>

# %%
plt.figure(figsize=(8,8))
ax1 = sns.countplot(x='hotel', hue='is_canceled', data=df)
plt.title("Hotels and their cancellations")
plt.legend(['Not cancelled', 'Cancelled'])
plt.show()

# %%
resort_hotel = df[df['hotel'] == 'Resort Hotel']
resort_hotel['is_canceled'].value_counts(normalize=True)
# Out:
# 0    0.72025
# 1    0.27975
# Name: is_canceled, dtype: float64

# %%
city_hotel = df[df['hotel'] == 'City Hotel']
city_hotel['is_canceled'].value_counts(normalize=True)
# Out:
# 1    0.765189
# 0    0.234811
# Name: is_canceled, dtype: float64

# %%
resort_hotel = resort_hotel.groupby('reservation_status_date')[['adr']].mean()
city_hotel = city_hotel.groupby('reservation_status_date')[['adr']].mean()

# %%
plt.figure(figsize=(8, 8))
plt.title("Average Daily Rate of the Two Hotels")
plt.plot(resort_hotel.index, resort_hotel['adr'], label='Resort Hotel')
plt.plot(city_hotel.index, city_hotel['adr'], label='City Hotel')
plt.legend(fontsize=12)
plt.show()

# %%
plt.figure(figsize = (8,8))
plt.title("Average Dailt Rate of the two Hotels")
plt.plot(resort_hotel.index, resort_hotel['adr'],label='Resort Hotel')
plt.plot(city_hotel.index, city_hotel['adr'],label='City Hotel')
plt.legend(fontsize=12)
plt.show()

# %%
df['month'] = df['reservation_status_date'].dt.month
# returns a new column 'month' from 'reservation_status_date'
plt.figure(figsize=(8,8))
ax2 = sns.countplot(x='month', hue='is_canceled', data=df)
plt.title("Reservation status per month")
plt.legend(['not cancelled', 'cancelled'])
plt.ylabel("no.of reservations")
# Out:
# Text(0, 0.5, 'no.of reservations')

# %%
madr = df[df['is_canceled'] ==1].groupby('month')[['adr']].sum().reset_index()
madr
# Out:
#     month        adr
# 0       1  313830.50
# 1       2  315699.29
# 2       3  285511.93
# 3       4  263397.00
# 4       5  239549.24
# 5       6  263193.23
# 6       7  321760.70
# 7       8  276480.08
# 8       9  227984.44
# 9      10  259464.45
# 10     11  143230.72
# 11     12  148682.73

# %%
plt.figure(figsize=(8,8))
plt.title("ADR per month", fontsize = 20)
sns.barplot(x='month', y='adr', data=madr)
# plot is between the month and average daily rate. filtering the dataframe when the room is cancelled and group it with the mnth column. we take the month index by reseting the index
# plt.show()
# Out:
# <Axes: title={'center': 'ADR per month'}, xlabel='month', ylabel='adr'>

# %%
cancelled_data = df[df['is_canceled'] == 1]
canc_country = cancelled_data['country'].value_counts()[:10]
plt.figure(figsize = (8,8))
plt.pie(canc_country, autopct = '%.2f', labels = canc_country.index)
plt.show()

# %%
df['market_segment'].value_counts()
# Out:
# Online TA        28789
# Offline TA/TO    12991
# Groups           11975
# Direct            7435
# Corporate         2576
# Complementary      260
# Aviation            28
# Name: market_segment, dtype: int64

# %%
df['market_segment'].value_counts(normalize=True)
# Out:
# Online TA        0.449449
# Offline TA/TO    0.202813
# Groups           0.186952
# Direct           0.116074
# Corporate        0.040216
# Complementary    0.004059
# Aviation         0.000437
# Name: market_segment, dtype: float64

# %%
cancelled_data['market_segment'].value_counts(normalize=True)
# Out:
# Online TA        0.506411
# Groups           0.238554
# Offline TA/TO    0.180115
# Direct           0.049778
# Corporate        0.022221
# Complementary    0.001980
# Aviation         0.000940
# Name: market_segment, dtype: float64

# %%
sns.barplot(x='market_segment', y='is_canceled', data=df)
plt.xlabel('Market Segment')
plt.ylabel('Canceled Bookings')
plt.title('Canceled Bookings by Market Segment')
plt.show()

# %%
cancelled_df_adr = cancelled_data.groupby('reservation_status_date')[['adr']].mean()
cancelled_df_adr.reset_index(inplace=True)
cancelled_df_adr.sort_values('reservation_status_date', inplace=True)

not_cancelled_data = df[df['is_canceled'] == 0]
not_cancelled_df_adr = not_cancelled_data.groupby('reservation_status_date')[['adr']].mean()
not_cancelled_df_adr.reset_index(inplace=True)
not_cancelled_df_adr.sort_values('reservation_status_date', inplace=True)

plt.figure(figsize=(18, 8))
plt.plot(not_cancelled_df_adr['reservation_status_date'], not_cancelled_df_adr['adr'], label='not_cancelled')
plt.plot(cancelled_df_adr['reservation_status_date'], cancelled_df_adr['adr'], label='cancelled')
plt.xlabel('Reservation Status Date')
plt.ylabel('ADR')
plt.title('Average Daily Rate (ADR) over Time')
plt.legend()
plt.show()

# %%
cancelled_df_adr = cancelled_df_adr[(cancelled_df_adr['reservation_status_date']>'2016')& (cancelled_df_adr['reservation_status_date']<'2017-09')]
not_cancelled_df_adr = not_cancelled_df_adr[(not_cancelled_df_adr['reservation_status_date']>'2016')& (not_cancelled_df_adr['reservation_status_date']<'2017-09')]
plt.figure(figsize=(20,6))
plt.plot(not_cancelled_df_adr['reservation_status_date'],not_cancelled_df_adr['adr'], label='Not cancelled')
plt.plot(cancelled_df_adr['reservation_status_date'],cancelled_df_adr['adr'], label='Cancelled')
plt.title("Average Daily rate")
plt.legend(fontsize=20)
